# %%
import pandas as pd
import datetime

# %%
def retorna_values(dataset,coluna):
    values = dataset.iloc[:,coluna]
    return values

# %%
dataCartao = pd.read_csv('CARTAO.txt', sep='\t')

# %%
dataCliente2017 = pd.read_csv('CLIENTES_2017', sep='\t')

# %%
df = dataCliente2017

# %%
lista_clientes = []
lista_datas = []
lista_dataLimites = []

for index, row in df.iterrows():
    dataCadastro = pd.to_datetime(row["DATA_CADASTRO"])
    dataLimite = dataCadastro + datetime.timedelta(days=180)
    lista_dataLimites.append(dataLimite)
    lista_datas.append(dataCadastro)
    lista_clientes.append(row['CODIGO_CLIENTE'])

# %%
dfC = dataCartao.head(500000)
dfC['DATA_CADASTRO'] = pd.NaT
dfC['DATA_LIMITE'] = pd.NaT
# Out:
# C:\Users\adans\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\adans\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x = 0
for index, row in dfC.iterrows():
    x=0
    for codigo in lista_clientes:
        if codigo == row['CODIGO_CLIENTE']:
            #row['DATA_CADASTRO'] = pd.to_datetime(lista_datas[x])
            dfC.set_value(index, 'DATA_CADASTRO', pd.to_datetime(lista_datas[x]))
            dfC.set_value(index, 'DATA_LIMITE', pd.to_datetime(lista_dataLimites[x]))
            print('Entrou no IF')
            print(row['CODIGO_CLIENTE'])
    x=x+1
# Out:
# C:\Users\adans\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\Users\adans\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Entrou no IF
# 1689
# Entrou no IF
# 1689
# Entrou no IF
# 1689
# Entrou no IF
# 1689
# Entrou no IF
# 1689
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 5140
# Entrou no IF
# 7376
# Entrou no IF
# 7376
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9042
# Entrou no IF
# 9945
# Entrou no IF
# 9945
# Entrou no IF
# 9945
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10161
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 10992
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 12400
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 15817
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 19314
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 20784
# Entrou no IF
# 21142
# Entrou no IF
# 21142
# Entrou no IF
# 21142
# Entrou no IF
# 21142
# Entrou no IF
# 21142
# Entrou no IF
# 21142
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 21364
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 22781
# Entrou no IF
# 24578
# Entrou no IF
# 24578
# Entrou no IF
# 24578
# Entrou no IF
# 24745
# Entrou no IF
# 24745
# Entrou no IF
# 27871
# Entrou no IF
# 27871
# Entrou no IF
# 27871
# Entrou no IF
# 27871
# Entrou no IF
# 28513
# Entrou no IF
# 28513
# Entrou no IF
# 28513
# Entrou no IF
# 28513
# Entrou no IF
# 28513
# Entrou no IF
# 28513
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 35305
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36374
# Entrou no IF
# 36595
# Entrou no IF
# 36595
# Entrou no IF
# 36595
# Entrou no IF
# 36595
# Entrou no IF
# 36595
# Entrou no IF
# 36595
# Entrou no IF
# 37353
# Entrou no IF
# 37353
# Entrou no IF
# 37353
# Entrou no IF
# 37353
# Entrou no IF
# 37353
# Entrou no IF
# 38082
# Entrou no IF
# 38082
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40006
# Entrou no IF
# 40044
# Entrou no IF
# 40044
# Entrou no IF
# 40044
# Entrou no IF
# 40044
# Entrou no IF
# 40044
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 40498
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 43256
# Entrou no IF
# 48051
# Entrou no IF
# 51899
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 53414
# Entrou no IF
# 55836
# Entrou no IF
# 55836
# Entrou no IF
# 55836
# Entrou no IF
# 55836
# Entrou no IF
# 55836
# Entrou no IF
# 55836
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 56111
# Entrou no IF
# 57752
# Entrou no IF
# 57752
# Entrou no IF
# 57752
# Entrou no IF
# 57752
# Entrou no IF
# 57752
# Entrou no IF
# 59400
# Entrou no IF
# 59400
# Entrou no IF
# 59400
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60300
# Entrou no IF
# 60424
# Entrou no IF
# 60424
# Entrou no IF
# 60424
# Entrou no IF
# 60424
# Entrou no IF
# 60424
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60508
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60892
# Entrou no IF
# 60964
# Entrou no IF
# 60964
# Entrou no IF
# 60964
# Entrou no IF
# 60964
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 60983
# Entrou no IF
# 61087
# Entrou no IF
# 61087
# Entrou no IF
# 61087
# Entrou no IF
# 61087
# Entrou no IF
# 61087
# Entrou no IF
# 61087
# Entrou no IF
# 61168
# Entrou no IF
# 61168
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61609
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 61700
# Entrou no IF
# 62022
# Entrou no IF
# 62022
# Entrou no IF
# 62022
# Entrou no IF
# 62022
# Entrou no IF
# 62022
# Entrou no IF
# 62022
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 62792
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 63458
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64198
# Entrou no IF
# 64534
# Entrou no IF
# 64534
# Entrou no IF
# 64534
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65008
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 65420
# Entrou no IF
# 66942
# Entrou no IF
# 66942
# Entrou no IF
# 66942
# Entrou no IF
# 66942
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67426
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67693
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 67913
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68190
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 68814
# Entrou no IF
# 69125
# Entrou no IF
# 69125
# Entrou no IF
# 69125
# Entrou no IF
# 69125
# Entrou no IF
# 69125
# Entrou no IF
# 70078
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 70374
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72569
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 72964
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74318
# Entrou no IF
# 74703
# Entrou no IF
# 74703
# Entrou no IF
# 74703
# Entrou no IF
# 74703
# Entrou no IF
# 74703
# Entrou no IF
# 74703
# Entrou no IF
# 74704
# Entrou no IF
# 74704
# Entrou no IF
# 74704
# Entrou no IF
# 74704
# Entrou no IF
# 74780
# Entrou no IF
# 74780
# Entrou no IF
# 74780
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 74872
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76277
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76312
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76447
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 76601
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78643
# Entrou no IF
# 78944
# Entrou no IF
# 78944
# Entrou no IF
# 78944
# Entrou no IF
# 78944
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81263
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81284
# Entrou no IF
# 81574
# Entrou no IF
# 81574
# Entrou no IF
# 82257
# Entrou no IF
# 82257
# Entrou no IF
# 82257
# Entrou no IF
# 82257
# Entrou no IF
# 83159
# Entrou no IF
# 83159
# Entrou no IF
# 83159
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84501
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 84902
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 86605
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 87347
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 88514
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89145
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89264
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 89475
# Entrou no IF
# 90172
# Entrou no IF
# 90172
# Entrou no IF
# 90172
# Entrou no IF
# 90172
# Entrou no IF
# 90172
# Entrou no IF
# 90172
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 90749
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94098
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 94297
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 102411
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 104356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 105356
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 107420
# Entrou no IF
# 108989
# Entrou no IF
# 108989
# Entrou no IF
# 108989
# Entrou no IF
# 108989
# Entrou no IF
# 108989
# Entrou no IF
# 108989
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 110056
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111603
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 111998
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 113289
# Entrou no IF
# 114359
# Entrou no IF
# 114359
# Entrou no IF
# 114359
# Entrou no IF
# 114359
# Entrou no IF
# 114359
# Entrou no IF
# 114359
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115195
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 115207
# Entrou no IF
# 116353
# Entrou no IF
# 116353
# Entrou no IF
# 116353
# Entrou no IF
# 116353
# Entrou no IF
# 116353
# Entrou no IF
# 116510
# Entrou no IF
# 116510
# Entrou no IF
# 116510
# Entrou no IF
# 116510
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116518
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 116540
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119298
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119638
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119642
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 119665
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139
# Entrou no IF
# 120139

# %%
for index, row in dfC.iterrows():
    if row['CODIGO_CLIENTE'] == 1689:
        print(row['CODIGO_CLIENTE'])
        print(row['DATA_CADASTRO'])
        print(row['DATA_LIMITE'])

# %%
dfC.to_csv("teste", sep='\t', encoding='utf-8')

# %%
dfC['FLAG_TARGET'] = 1
dfC["FLAG_ELEGIVEL"] = 1

# %%
for index, row in dfC.iterrows():
    dataPagamento = pd.to_datetime(row["DATA_PAGAMENTO"])
    dataVencimento = pd.to_datetime(row["DATA_VENCIMENTO"])
    if dataPagamento <= dataVencimento:
        dfC.set_value(index, 'FLAG_TARGET', 0)
    else:
        dfC.set_value(index, 'FLAG_TARGET', 1)
    if (pd.to_datetime(row['DATA_CADASTRO']) is pd.NaT) | (pd.to_datetime(row['DATA_CADASTRO']) > pd.to_datetime(row['DATA_PAGAMENTO'])) | (pd.to_datetime(row['DATA_LIMITE']) >= pd.to_datetime(row['DATA_PAGAMENTO'])):
        dfC.set_value(index, 'FLAG_ELEGIVEL', 1)
    elif (pd.to_datetime(row['DATA_CADASTRO']) <= pd.to_datetime(row['DATA_PAGAMENTO'])) & (pd.to_datetime(row['DATA_PAGAMENTO']) <= pd.to_datetime(row['DATA_LIMITE'])):
        dfC.set_value(index, 'FLAG_ELEGIVEL', 0)
        print(index)

# %%
dfC.to_csv("TABELAO_CARTAO", sep='\t', encoding='utf-8')

# %% [markdown]
# for index, row in dfC2.iterrows():
#     dataPagamento = pd.to_datetime(row["DATA_PAGAMENTO"])
#     dataVencimento = pd.to_datetime(row["DATA_VENCIMENTO"])
#     if dataPagamento <= dataVencimento:
#         dfC2.set_value(index, 'FLAG_TARGET', 0)
#     else:
#         dfC2.set_value(index, 'FLAG_TARGET', 1)
#     if (row['DATA_CADASTRO'] is pd.NaT) | (row['DATA_CADASTRO'] > row['DATA_PAGAMENTO']) | (row['DATA_LIMITE'] >= row['DATA_PAGAMENTO']):
#         dfC2.set_value(index, 'FLAG_ELEGIVEL', 1)
#     elif (row['DATA_CADASTRO'] <= row['DATA_PAGAMENTO']) & (row['DATA_PAGAMENTO'] <= row['DATA LIMITE']):
#         dfC2.set_value(index, 'FLAG_ELEGIVEL', 0)
